# %% [markdown]
# <a href="https://colab.research.google.com/github/SakshiBisht584/FirstRepo/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import all the needed libraries
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets,model_selection,linear_model

# %%
X,y=datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(y.shape)
print(X)
# Out:
# (442, 10)
# (442,)
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %%
X=X[:,2]
#Reshape to a 2D array
X=X.reshape((-1,1))
print(X.shape)
# Out:
# (442, 1)

# %%
#spliting data into training and testing data
X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.33)

# %%
#creating linear regression model and train it with our data
model=linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
#creating a scatter plot
plt.scatter(X_test,y_test,c='r')

#ploting the predictions
plt.plot(X_test,y_pred,c='b')

#labeling
plt.xlabel("Scaled BMI")
plt.ylabel("Disease Progression")

#showing the plot
plt.show()
